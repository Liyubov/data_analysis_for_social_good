# %% [markdown]
# ### Data analysis for paleo data
#
# This notebook is dedicated to the project of data analysis of paleo metadata.
#
#
# **Temporal analysis**.
# We first start with temporal evolution of each group of each of paleo groups to show the growth of number of findings.
#
# **Spatial analysis**.
# Then we also dig into the spatial resolution of data.
#
# *Authors: Jon, Liuba, et al.*

# %%
# Import the pandas library.
import pandas
import csv
import numpy as np
import pandas

# Read in the paleo data.
paleodata = pandas.read_csv("C:/Users/lyubo/Documents/DATA_networks/paleodata.dat", header=None, dtype=str)

paleodata.columns = ["id", "name", "latitude", "longitude", "altitude", "timezone", "type", "time"]

# let us look at the data 

paleodata.head()

# %% [markdown]
# **Temporal analysis**

# %%
import seaborn


# group_in_time is variable which has temporal evolution of species in time 
# to be inserted here 

seaborn.distplot(group_in_time, bins=20)
plt.show()

# %% [markdown]
# **Spatial analysis**

# %%
# Import the basemap package
# for plotting paleodata on a map
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# Create a map on which to draw. 
# Use mercator projection, and showing the whole world.
m = Basemap(projection='merc',llcrnrlat=-80,urcrnrlat=80,llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')
# Draw coastlines, and the edges of the map.
# Convert latitude and longitude to x and y coordinates
x, y = m(list(paleodata["longitude"].astype(float)), list(paleodata["latitude"].astype(float)))

# Use matplotlib to draw the points onto the map.
m.scatter(x,y,1,marker='o',color='red')
# Show the plot.

m.drawcoastlines()
m.drawmapboundary()

plt.show()
# Out:
# C:\Users\lyubo\Anaconda3\envs\default\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %% [markdown]
# work in progress (the records wil be inserted there soon)...
